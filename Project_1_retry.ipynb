# %%
#Goal: View NYC school Data and  compare scores of the 2017 Regents Exam for "Living Enironment"
# from  2 schools: Icahn Charter School and The Island Schools.  They are both k-8th; I teach at a k-8th in middle school

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df.describe
# Out:
# <bound method NDFrame.describe of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
#what does data look like?
df.head
# Out:
# <bound method NDFrame.head of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212325     84X717            Icahn Charter School          K-8
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 1        Living Environment  2015            16       77.9
# ...

# %%
##
#Use Filtering rows with exact matchiing.  df[df['column name']=='value']
# I do not know how to compare two schools at the same time.

df_Icahn=df[(df['School Name']=='Icahn Charter School')&  (df['Regents Exam']=='Living Environment')& (df['Year']==2017)]
#df_Icahn[['School Name', 'Regents Exam', 'Year', 'Mean Score']]
df_Icahn
# Out:
#        School DBN           School Name School Level        Regents Exam  \
# 19476      84X717  Icahn Charter School          K-8  Living Environment
# 54232      84X717  Icahn Charter School          K-8  Living Environment
# 102876     84X717  Icahn Charter School          K-8  Living Environment
# 102877     84X717  Icahn Charter School          K-8  Living Environment
# 139881     84X717  Icahn Charter School          K-8  Living Environment
# 139882     84X717  Icahn Charter School          K-8  Living Environment
# 212328     84X717  Icahn Charter School          K-8  Living Environment
# 212329     84X717  Icahn Charter School          K-8  Living Environment
#
#         Year  Total Tested Mean Score Number Scoring Below 65  \
# 19476   2017            10       79.7                       0
# 54232   2017            10       79.7                       0
# 102876  2017             9          s                       s
# ...

# %%
#Use Filtering rows with exact matchiing.  df[df['column name']=='value']
# I do not know how to compare two schools at the same time.
#The Island School Scores for Living Environment Exam in 2017
#Data is not showing


df_Island=df[(df['School Name']=='The Island School')& (df['Regents Exam']=='Living Environment')& (df['Year']==2017)]
df_Island
# Out:
# Empty DataFrame
# Columns: [School DBN, School Name, School Level, Regents Exam, Year, Total Tested, Mean Score, Number Scoring Below 65, Percent Scoring Below 65, Number Scoring 65 or Above, Percent Scoring 65 or Above, Number Scoring 80 or Above, Percent Scoring 80 or Above, Number Scoring CR, Percent Scoring CR]
# Index: []

# %%
#Attemting to show both schools data

#df.loc[df['col1'].isin([value1, value2, value3, ...])]
#df_InterestingSchools=df.loc[df['School Name'].isin(['Icahn Charter School', 'The Island School'])&  (df['Regents Exam']=='Living Environment')& (df['Year']==2017)]
#df_Icahn[['School Name', 'Regents Exam', 'Year', 'Mean Score']]
#df_InterestingSchools=df[(df['School Name'].isin(['Icahn Charter School','The Island School'])&  (df['Regents Exam']=='Living Environment')& (df['Year']==2017))]
#df_InterestingSchools

#this did not work. It only shows Icahn Charter School's data
# Out:
# Empty DataFrame
# Columns: [School DBN, School Name, School Level, Regents Exam, Year, Total Tested, Mean Score, Number Scoring Below 65, Percent Scoring Below 65, Number Scoring 65 or Above, Percent Scoring 65 or Above, Number Scoring 80 or Above, Percent Scoring 80 or Above, Number Scoring CR, Percent Scoring CR]
# Index: []

# %%
df3=df_Icahn[['School Name', 'Regents Exam', 'Mean Score', 'Year']]
df3
# Out:
#                  School Name        Regents Exam Mean Score  Year
# 19476   Icahn Charter School  Living Environment       79.7  2017
# 54232   Icahn Charter School  Living Environment       79.7  2017
# 102876  Icahn Charter School  Living Environment          s  2017
# 102877  Icahn Charter School  Living Environment          s  2017
# 139881  Icahn Charter School  Living Environment          s  2017
# 139882  Icahn Charter School  Living Environment          s  2017
# 212328  Icahn Charter School  Living Environment          s  2017
# 212329  Icahn Charter School  Living Environment          s  2017

# %%
# drop all rows that contain mean score 's'
df4 = df3.drop(df3[df3['Mean Score'] == 's'].index)
print(df4)
# Out:
#                 School Name        Regents Exam Mean Score  Year
# 19476  Icahn Charter School  Living Environment       79.7  2017
# 54232  Icahn Charter School  Living Environment       79.7  2017

# %%
#Where is my data?  I don't understand why it doesnt show any?

df_5=df_Island[['Regents Exam', 'Mean Score', 'Year']]
df_5
# Out:
# Empty DataFrame
# Columns: [Regents Exam, Mean Score, Year]
# Index: []

# %%
df6 = df5.drop(df5[df5['Mean Score'] == 's'].index)
print(df6)
# Out:
#                 School Name        Regents Exam Mean Score  Year
# 19476  Icahn Charter School  Living Environment       79.7  2017
# 54232  Icahn Charter School  Living Environment       79.7  2017

# %%
#I am attempting to show both schools' data, but for whatever reason, the data is not showing up
df7=df_InterestingSchools[['School Name','Regents Exam', 'Mean Score', 'Year']]
df7
# Out:
# Empty DataFrame
# Columns: [School Name, Regents Exam, Mean Score, Year]
# Index: []

# %%
#Summary:  I unfortunately was not succeful in this project.  I do not understand why I was unable to pull the data through for "The Island School".

# %%
#Want to get rid of the "s" because I want to focus on the mean scores.
d8=df7.drop(df7[df7['Mean Score'] == 's'].index)
print(d8)
# Out:
#                 School Name        Regents Exam Mean Score  Year
# 19476  Icahn Charter School  Living Environment       79.7  2017
# 54232  Icahn Charter School  Living Environment       79.7  2017

# %%
df3.plot(kind="bar")
# Out:
# <Axes: >
